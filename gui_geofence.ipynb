# %%
import cv2
import numpy as np
import pandas as pd
from tkinter import Tk, Button, filedialog
from shapely.geometry import Polygon
from ultralytics import YOLO
from tracker import Tracker

class VideoProcessor:
    def __init__(self):
        self.polygon_points = []
        self.video_path = ""
        self.clone = None

    def draw_polygon(self, image, points):
        points = np.array(points, np.int32)
        points = points.reshape((-1, 1, 2))
        cv2.polylines(image, [points], True, (0, 255, 0), 2)

    def store_polygon_coordinates(self, points, filename):
        with open(filename, "w") as file:
            for point in points:
                file.write(f"{point[0]},{point[1]}\n")

    def load_polygon_coordinates(self, filename):
        points = []
        with open(filename, "r") as file:
            for line in file:
                x, y = map(int, line.strip().split(","))
                points.append((x, y))
        return points

    def upload_video(self):
        self.video_path = filedialog.askopenfilename()
        cap = cv2.VideoCapture(self.video_path)
        ret, first_frame = cap.read()  # Add this line to capture the first frame of the video

        # Load the YOLO model
        yolo_model = YOLO('best (18).pt')

        
        # Define the class list
        my_file = open("coco.txt", "r")
        data = my_file.read()
        class_list = data.split("\n")

        # Define the tracker
        tracker = Tracker()

        def on_mouse(event, x, y, flags, param):
            if event == cv2.EVENT_LBUTTONDOWN:
                self.polygon_points.append((x, y))
                if len(self.polygon_points) > 1:
                    self.draw_polygon(self.clone, self.polygon_points)
            elif event == cv2.EVENT_MOUSEMOVE and flags == cv2.EVENT_FLAG_LBUTTON:
                self.polygon_points.append((x, y))
                self.draw_polygon(self.clone, self.polygon_points)
            elif event == cv2.EVENT_RBUTTONDOWN:
                if len(self.polygon_points) > 2:
                    self.draw_polygon(self.clone, self.polygon_points)
                    cv2.line(self.clone, self.polygon_points[-1], self.polygon_points[0], (0, 0, 255), 2)  # Close the polygon
                self.store_polygon_coordinates(self.polygon_points, "polygon_coordinates.txt")

        self.clone = first_frame.copy()
        cv2.namedWindow("Draw Polygon", cv2.WINDOW_NORMAL)  # Set the window to be resizable
        cv2.resizeWindow("Draw Polygon", 800, 800)  # Set the window size for better visibility
        cv2.setMouseCallback("Draw Polygon", on_mouse)

        while True:
            cv2.imshow("Draw Polygon", self.clone)
            key = cv2.waitKey(1) & 0xFF
            if key == 27:  # Escape key
                break

        cv2.destroyAllWindows()

        screen_res = (1920, 1080)
        scale_width = screen_res[0] / first_frame.shape[1]
        scale_height = screen_res[1] / first_frame.shape[0]
        scale = min(scale_width, scale_height)
        window_width = int(first_frame.shape[1] * scale)
        window_height = int(first_frame.shape[0] * scale)

        cv2.namedWindow("Person detection", cv2.WINDOW_NORMAL)
        cv2.resizeWindow("Person detection", window_width, window_height)

        while True:
            ret, frame = cap.read()
            frame_copy = frame.copy()
            if not ret:
                break
            frame = cv2.resize(frame, (window_width, window_height))
            results = yolo_model.predict(frame)
            a = results[0].boxes.data
            px = pd.DataFrame(a).astype("float")
            list = []
            for index, row in px.iterrows():
                x1 = int(row[0])
                y1 = int(row[1])
                x2 = int(row[2])
                y2 = int(row[3])
                d = int(row[5])
                c = class_list[d]
                if 'person' in c:
                    list.append([x1, y1, x2, y2])
            bbox_idx = tracker.update(list)
            for bbox in bbox_idx:
                x3, y3, x4, y4, id = bbox
                a = (x3 + x4)/2
                b = (y3 + y4)/2
                result = cv2.pointPolygonTest(np.array(self.polygon_points, np.int32), ((a, b)), False)
                if result <= 0:
                    cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 2)
                    cv2.putText(frame, 'person', (x3, y3-15), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 255), 2, cv2.LINE_4)
            self.draw_polygon(frame, self.polygon_points)
            cv2.imshow("Person detection", frame)
            if cv2.waitKey(1) & 0xFF == 27:
                break

        cap.release()
        cv2.destroyAllWindows()

root = Tk()
root.geometry("400x200")

processor = VideoProcessor()

upload_button = Button(root, text="Upload Video", command=processor.upload_video)
upload_button.pack()

root.mainloop()
# Out:
# 0: 480x800 8 Persons, 3376.8ms
# Speed: 5.7ms preprocess, 3376.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2787.9ms
# Speed: 2.1ms preprocess, 2787.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2397.2ms
# Speed: 2.1ms preprocess, 2397.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 3283.1ms
# Speed: 22.7ms preprocess, 3283.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2041.0ms
# Speed: 4.6ms preprocess, 2041.0ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 1959.7ms
# Speed: 3.0ms preprocess, 1959.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 1886.5ms
# Speed: 11.4ms preprocess, 1886.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2119.3ms
# Speed: 10.8ms preprocess, 2119.3ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 1919.5ms
# Speed: 2.0ms preprocess, 1919.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2245.1ms
# Speed: 4.7ms preprocess, 2245.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2762.2ms
# Speed: 2.0ms preprocess, 2762.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2491.0ms
# Speed: 19.1ms preprocess, 2491.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 1933.3ms
# Speed: 6.2ms preprocess, 1933.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 1975.9ms
# Speed: 5.2ms preprocess, 1975.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2109.6ms
# Speed: 2.7ms preprocess, 2109.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2166.7ms
# Speed: 1.0ms preprocess, 2166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2716.4ms
# Speed: 2.0ms preprocess, 2716.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2028.1ms
# Speed: 2.0ms preprocess, 2028.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2209.4ms
# Speed: 2.0ms preprocess, 2209.4ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2294.6ms
# Speed: 1.7ms preprocess, 2294.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2099.5ms
# Speed: 7.6ms preprocess, 2099.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2100.2ms
# Speed: 18.6ms preprocess, 2100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2477.6ms
# Speed: 5.3ms preprocess, 2477.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2188.4ms
# Speed: 1.0ms preprocess, 2188.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 3466.3ms
# Speed: 3.0ms preprocess, 3466.3ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2606.0ms
# Speed: 23.9ms preprocess, 2606.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2713.1ms
# Speed: 4.0ms preprocess, 2713.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 5 Persons, 2750.2ms
# Speed: 1.0ms preprocess, 2750.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2215.7ms
# Speed: 1.0ms preprocess, 2215.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 1944.0ms
# Speed: 2.3ms preprocess, 1944.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2326.2ms
# Speed: 3.5ms preprocess, 2326.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2952.3ms
# Speed: 2.0ms preprocess, 2952.3ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 1952.6ms
# Speed: 18.2ms preprocess, 1952.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 1893.8ms
# Speed: 1.4ms preprocess, 1893.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 5 Persons, 2390.2ms
# Speed: 1.3ms preprocess, 2390.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 5 Persons, 2274.6ms
# Speed: 5.6ms preprocess, 2274.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2071.0ms
# Speed: 2.3ms preprocess, 2071.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2445.5ms
# Speed: 4.1ms preprocess, 2445.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2513.2ms
# Speed: 2.9ms preprocess, 2513.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2378.5ms
# Speed: 20.6ms preprocess, 2378.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2519.7ms
# Speed: 1.0ms preprocess, 2519.7ms inference, 17.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2440.0ms
# Speed: 4.6ms preprocess, 2440.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2313.5ms
# Speed: 6.7ms preprocess, 2313.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2285.4ms
# Speed: 5.8ms preprocess, 2285.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 1924.1ms
# Speed: 4.0ms preprocess, 1924.1ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2559.5ms
# Speed: 14.2ms preprocess, 2559.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 1980.6ms
# Speed: 6.5ms preprocess, 1980.6ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2044.7ms
# Speed: 2.0ms preprocess, 2044.7ms inference, 16.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 Persons, 2116.6ms
# Speed: 14.9ms preprocess, 2116.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2376.4ms
# Speed: 3.0ms preprocess, 2376.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 Persons, 2160.9ms
# Speed: 2.0ms preprocess, 2160.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2334.8ms
# Speed: 17.9ms preprocess, 2334.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2194.1ms
# Speed: 4.7ms preprocess, 2194.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2571.2ms
# Speed: 2.3ms preprocess, 2571.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2447.2ms
# Speed: 6.5ms preprocess, 2447.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 5 Persons, 2947.3ms
# Speed: 2.0ms preprocess, 2947.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 5 Persons, 2159.3ms
# Speed: 2.0ms preprocess, 2159.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2617.4ms
# Speed: 20.1ms preprocess, 2617.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 1902.4ms
# Speed: 16.7ms preprocess, 1902.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2734.4ms
# Speed: 17.3ms preprocess, 2734.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 4 Persons, 2226.0ms
# Speed: 6.7ms preprocess, 2226.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2095.8ms
# Speed: 3.0ms preprocess, 2095.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 1903.5ms
# Speed: 4.1ms preprocess, 1903.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2055.6ms
# Speed: 4.0ms preprocess, 2055.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2206.1ms
# Speed: 2.1ms preprocess, 2206.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2556.4ms
# Speed: 3.0ms preprocess, 2556.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 Persons, 2689.7ms
# Speed: 1.0ms preprocess, 2689.7ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 2060.6ms
# Speed: 2.0ms preprocess, 2060.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 Persons, 1932.7ms
# Speed: 1.0ms preprocess, 1932.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 5 Persons, 2186.8ms
# Speed: 3.7ms preprocess, 2186.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 5 Persons, 2523.6ms
# Speed: 16.9ms preprocess, 2523.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
